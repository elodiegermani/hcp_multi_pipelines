# %%
from lib import spm_pipelines, fsl_pipelines

from os.path import join as opj
import os
# Out:
# Traceback (most recent call last):
#
#   File "/Users/egermani/miniforge3/envs/workEnv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/var/folders/k4/cck9mrt578q044z6x6zmsnc400m_jt/T/ipykernel_42266/272938655.py", line 1, in <module>
#     from lib import spm_pipelines, fsl_pipelines
#
#   File "/Users/egermani/Documents/hcp_pipelines/src/lib/spm_pipelines.py", line 160
#     os.system(f'bash {os.path.dirname(filePath)+'/'}mp_diffpow24.sh {param_file} {out_file}')
#                                                  ^
# SyntaxError: f-string: expecting '}'

# %%
exp_dir = '/home/hcp/data'
result_dir = '/home/hcp'

working_dir = 'spm_preprocessing/intermediate_results'
output_dir = 'spm_preprocessing'

subject_list = ['100206', '100307', '100408', '100610', '101006', '101107', '101309', '101410', '101915', '102008', 
                '102109', '102311', '102513', '102614', '102715', '102816', '103010', '103111', '103212', '103414', 
                '103515', '103818']

task_list = ['MOTOR']

contrast_list = ['cue','lf', 'rf', 'rh', 'lh', 't']
print(list(range(1, len(contrast_list)+1)))

fwhm_list = [8]
print(fwhm_list)

#preprocess = spm_pipelines.get_preprocessing(exp_dir, result_dir, working_dir, output_dir, subject_list, task_list, 
#                                            fwhm_list)
# Out:
# [1, 2, 3, 4, 5, 6]
# [8]

# %%
preprocess.run('MultiProc', plugin_args={'n_procs': 6})
# Out:
# 220927-14:17:05,875 nipype.workflow INFO:
# 	 Workflow preprocess_spm settings: ['check', 'execution', 'logging', 'monitoring']
# 220927-14:17:06,102 nipype.workflow INFO:
# 	 Running in parallel.
# 220927-14:17:06,108 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 14 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 6/6.
# 220927-14:17:06,266 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_101915_task_MOTOR/selectfiles_preproc".
# 220927-14:17:06,280 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102008_task_MOTOR/selectfiles_preproc".
# 220927-14:17:06,292 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102109_task_MOTOR/selectfiles_preproc".
# 220927-14:17:06,297 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102311_task_MOTOR/selectfiles_preproc".
# 220927-14:17:06,313 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102513_task_MOTOR/selectfiles_preproc".
# 220927-14:17:06,330 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102614_task_MOTOR/selectfiles_preproc".
# 220927-14:17:06,408 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:06,420 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:06,422 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.00793s.
# 220927-14:17:06,446 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.016721s.
# 220927-14:17:06,479 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:06,484 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:06,506 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.012877s.
# 220927-14:17:06,524 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.004397s.
# 220927-14:17:06,544 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:06,546 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:06,577 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.018047s.
# 220927-14:17:06,601 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.031968s.
# 220927-14:17:08,120 nipype.workflow INFO:
# 	 [Job 0] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:08,126 nipype.workflow INFO:
# 	 [Job 1] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:08,129 nipype.workflow INFO:
# 	 [Job 2] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:08,134 nipype.workflow INFO:
# 	 [Job 3] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:08,138 nipype.workflow INFO:
# 	 [Job 4] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:08,142 nipype.workflow INFO:
# 	 [Job 5] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:08,146 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 20 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 6/6.
# 220927-14:17:08,290 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102715_task_MOTOR/selectfiles_preproc".
# 220927-14:17:08,297 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102816_task_MOTOR/selectfiles_preproc".
# 220927-14:17:08,308 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103010_task_MOTOR/selectfiles_preproc".
# 220927-14:17:08,320 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103111_task_MOTOR/selectfiles_preproc".
# 220927-14:17:08,344 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103212_task_MOTOR/selectfiles_preproc".
# 220927-14:17:08,362 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103414_task_MOTOR/selectfiles_preproc".
# 220927-14:17:08,366 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:08,378 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.005102s.
# 220927-14:17:08,409 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:08,422 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.005743s.
# 220927-14:17:08,437 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:08,453 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.011804s.
# 220927-14:17:08,453 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:08,464 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.000557s.
# 220927-14:17:08,490 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:08,505 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:08,503 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.005551s.
# 220927-14:17:08,532 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.004223s.
# 220927-14:17:10,116 nipype.workflow INFO:
# 	 [Job 6] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:10,120 nipype.workflow INFO:
# 	 [Job 7] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:10,123 nipype.workflow INFO:
# 	 [Job 8] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:10,126 nipype.workflow INFO:
# 	 [Job 9] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:10,129 nipype.workflow INFO:
# 	 [Job 10] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:10,132 nipype.workflow INFO:
# 	 [Job 11] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:10,135 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 26 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 6/6.
# 220927-14:17:10,236 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103515_task_MOTOR/selectfiles_preproc".
# 220927-14:17:10,245 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.selectfiles_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103818_task_MOTOR/selectfiles_preproc".
# 220927-14:17:10,255 nipype.workflow INFO:
# 	 [Job 14] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:10,283 nipype.workflow INFO:
# 	 [Job 15] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:10,299 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.gunzip_func" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102008_task_MOTOR/gunzip_func".
# 220927-14:17:10,308 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:10,311 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.gunzip_anat" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102008_task_MOTOR/gunzip_anat".
# 220927-14:17:10,320 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.003151s.
# 220927-14:17:10,341 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_preproc" <nipype.interfaces.io.SelectFiles>
# 220927-14:17:10,355 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_preproc", elapsed time 0.005705s.
# 220927-14:17:10,359 nipype.workflow INFO:
# 	 [Node] Executing "gunzip_func" <nipype.algorithms.misc.Gunzip>
# 220927-14:17:10,403 nipype.workflow INFO:
# 	 [Node] Executing "gunzip_anat" <nipype.algorithms.misc.Gunzip>
# 220927-14:17:12,117 nipype.workflow INFO:
# 	 [Job 12] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:12,120 nipype.workflow INFO:
# 	 [Job 13] Completed (preprocess_spm.selectfiles_preproc).
# 220927-14:17:12,125 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 26 jobs ready. Free memory (GB): 6.51/6.91, Free processors: 4/6.
#                      Currently running:
#                        * preprocess_spm.gunzip_anat
#                        * preprocess_spm.gunzip_func
# 220927-14:17:12,303 nipype.workflow INFO:
# 	 [Job 18] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:12,331 nipype.workflow INFO:
# 	 [Job 19] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:12,358 nipype.workflow INFO:
# 	 [Job 20] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:12,378 nipype.workflow INFO:
# 	 [Job 21] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:12,750 nipype.workflow INFO:
# 	 [Node] Finished "gunzip_anat", elapsed time 2.342193s.
# 220927-14:17:14,117 nipype.workflow INFO:
# 	 [Job 17] Completed (preprocess_spm.gunzip_anat).
# 220927-14:17:14,125 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 27 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 5/6.
#                      Currently running:
#                        * preprocess_spm.gunzip_func
# 220927-14:17:14,277 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.gunzip_func" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102513_task_MOTOR/gunzip_func".
# 220927-14:17:14,281 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.gunzip_anat" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102513_task_MOTOR/gunzip_anat".
# 220927-14:17:14,315 nipype.workflow INFO:
# 	 [Job 24] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:14,359 nipype.workflow INFO:
# 	 [Job 25] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:14,363 nipype.workflow INFO:
# 	 [Node] Executing "gunzip_func" <nipype.algorithms.misc.Gunzip>
# 220927-14:17:14,369 nipype.workflow INFO:
# 	 [Node] Executing "gunzip_anat" <nipype.algorithms.misc.Gunzip>
# 220927-14:17:14,404 nipype.workflow INFO:
# 	 [Job 26] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:16,119 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 25 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 3/6.
#                      Currently running:
#                        * preprocess_spm.gunzip_anat
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
# 220927-14:17:16,245 nipype.workflow INFO:
# 	 [Job 27] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:16,278 nipype.workflow INFO:
# 	 [Job 28] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:16,300 nipype.workflow INFO:
# 	 [Job 29] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:17,476 nipype.workflow INFO:
# 	 [Node] Finished "gunzip_anat", elapsed time 3.090837s.
# 220927-14:17:18,119 nipype.workflow INFO:
# 	 [Job 23] Completed (preprocess_spm.gunzip_anat).
# 220927-14:17:18,124 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 26 jobs ready. Free memory (GB): 6.51/6.91, Free processors: 4/6.
#                      Currently running:
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
# 220927-14:17:18,281 nipype.workflow INFO:
# 	 [Job 30] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:18,300 nipype.workflow INFO:
# 	 [Job 31] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:18,323 nipype.workflow INFO:
# 	 [Job 32] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:18,352 nipype.workflow INFO:
# 	 [Job 33] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:20,283 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.gunzip_func" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103212_task_MOTOR/gunzip_func".
# 220927-14:17:20,293 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.gunzip_anat" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103212_task_MOTOR/gunzip_anat".
# 220927-14:17:20,332 nipype.workflow INFO:
# 	 [Job 36] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:20,364 nipype.workflow INFO:
# 	 [Job 37] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:20,394 nipype.workflow INFO:
# 	 [Node] Executing "gunzip_func" <nipype.algorithms.misc.Gunzip>
# 220927-14:17:20,409 nipype.workflow INFO:
# 	 [Node] Executing "gunzip_anat" <nipype.algorithms.misc.Gunzip>
# 220927-14:17:22,122 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 24 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 2/6.
#                      Currently running:
#                        * preprocess_spm.gunzip_anat
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
# 220927-14:17:22,253 nipype.workflow INFO:
# 	 [Job 38] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:22,284 nipype.workflow INFO:
# 	 [Job 39] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:23,840 nipype.workflow INFO:
# 	 [Node] Finished "gunzip_anat", elapsed time 3.419968s.
# 220927-14:17:24,263 nipype.workflow INFO:
# 	 [Job 40] Cached (preprocess_spm.gunzip_func).
# 220927-14:17:24,286 nipype.workflow INFO:
# 	 [Job 41] Cached (preprocess_spm.gunzip_anat).
# 220927-14:17:26,125 nipype.workflow INFO:
# 	 [Job 35] Completed (preprocess_spm.gunzip_anat).
# 220927-14:17:26,127 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 25 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 3/6.
#                      Currently running:
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
# 220927-14:17:26,344 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_101915_task_MOTOR/motion_correction".
# 220927-14:17:26,372 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_101915_task_MOTOR/seg".
# 220927-14:17:26,377 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102008_task_MOTOR/seg".
# 220927-14:17:26,511 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:17:26,536 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:17:28,133 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 22 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
# 220927-14:17:30,640 nipype.workflow INFO:
# 	 [Node] Finished "gunzip_func", elapsed time 20.27254s.
# 220927-14:17:32,111 nipype.workflow INFO:
# 	 [Job 16] Completed (preprocess_spm.gunzip_func).
# 220927-14:17:32,118 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 23 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
# 220927-14:17:32,424 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102008_task_MOTOR/motion_correction".
# 220927-14:17:34,115 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 22 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.gunzip_func
#                        * preprocess_spm.gunzip_func
# 220927-14:17:37,733 nipype.workflow INFO:
# 	 [Node] Finished "gunzip_func", elapsed time 23.364763s.
# 220927-14:17:38,116 nipype.workflow INFO:
# 	 [Job 22] Completed (preprocess_spm.gunzip_func).
# 220927-14:17:38,120 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 23 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.gunzip_func
# 220927-14:17:38,340 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102109_task_MOTOR/motion_correction".
# 220927-14:17:40,120 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 22 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.gunzip_func
# 220927-14:17:45,490 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:17:46,486 nipype.workflow INFO:
# 	 [Node] Finished "gunzip_func", elapsed time 26.086369s.
# 220927-14:17:48,124 nipype.workflow INFO:
# 	 [Job 34] Completed (preprocess_spm.gunzip_func).
# 220927-14:17:48,140 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 23 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
# 220927-14:17:48,454 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102109_task_MOTOR/seg".
# 220927-14:17:48,595 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:17:50,133 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 22 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
# 220927-14:17:51,524 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:17:53,482 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:23:50,417 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 364.919349s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:23:50,745 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 359.199912s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:23:52,254 nipype.workflow INFO:
# 	 [Job 42] Completed (preprocess_spm.motion_correction).
# 220927-14:23:52,256 nipype.workflow INFO:
# 	 [Job 44] Completed (preprocess_spm.motion_correction).
# 220927-14:23:52,260 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 24 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 2/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:23:52,448 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102311_task_MOTOR/motion_correction".
# 220927-14:23:52,459 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102311_task_MOTOR/seg".
# 220927-14:23:52,533 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:23:54,264 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 22 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:23:57,795 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:24:05,173 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 371.673793s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:24:06,247 nipype.workflow INFO:
# 	 [Job 46] Completed (preprocess_spm.motion_correction).
# 220927-14:24:06,250 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 23 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:24:06,388 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102513_task_MOTOR/motion_correction".
# 220927-14:24:08,251 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 22 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:24:14,451 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:28:08,575 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 642.028605s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:28:10,325 nipype.workflow INFO:
# 	 [Job 43] Completed (preprocess_spm.seg).
# 220927-14:28:10,331 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 22 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:28:10,539 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102513_task_MOTOR/seg".
# 220927-14:28:10,607 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:28:12,329 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 21 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:28:20,677 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 654.15486s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:28:22,340 nipype.workflow INFO:
# 	 [Job 45] Completed (preprocess_spm.seg).
# 220927-14:28:22,346 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 21 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# 220927-14:28:22,570 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102614_task_MOTOR/motion_correction".
# 220927-14:28:24,340 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 20 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# 220927-14:28:31,318 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:29:37,487 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 339.673793s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:29:38,348 nipype.workflow INFO:
# 	 [Job 48] Completed (preprocess_spm.motion_correction).
# 220927-14:29:38,352 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 21 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:29:38,541 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102614_task_MOTOR/seg".
# 220927-14:29:38,606 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:29:40,172 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 711.570647s.
# 220927-14:29:40,350 nipype.workflow INFO:
# 	 [Job 47] Completed (preprocess_spm.seg).
# 220927-14:29:40,355 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 20 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:29:40,576 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102715_task_MOTOR/motion_correction".
# 220927-14:29:42,359 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 19 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# 220927-14:29:48,755 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:30:02,825 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 348.359062s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:30:04,351 nipype.workflow INFO:
# 	 [Job 50] Completed (preprocess_spm.motion_correction).
# 220927-14:30:04,353 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 20 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:30:04,530 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102715_task_MOTOR/seg".
# 220927-14:30:04,598 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:30:06,353 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 19 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:33:59,24 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 606.472552s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:34:00,420 nipype.workflow INFO:
# 	 [Job 49] Completed (preprocess_spm.seg).
# 220927-14:34:00,424 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 19 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# 220927-14:34:00,597 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102816_task_MOTOR/motion_correction".
# 220927-14:34:02,432 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 18 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# 220927-14:34:18,607 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:34:28,736 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 357.402953s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:34:30,429 nipype.workflow INFO:
# 	 [Job 52] Completed (preprocess_spm.motion_correction).
# 220927-14:34:30,432 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 19 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:34:30,566 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102816_task_MOTOR/seg".
# 220927-14:34:30,615 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:34:32,431 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 18 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:35:36,775 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 348.007348s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:35:38,455 nipype.workflow INFO:
# 	 [Job 54] Completed (preprocess_spm.motion_correction).
# 220927-14:35:38,458 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 19 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:35:38,699 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103010_task_MOTOR/motion_correction".
# 220927-14:35:40,457 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 18 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:35:47,889 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:39:10,326 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 659.702884s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:39:10,531 nipype.workflow INFO:
# 	 [Job 51] Completed (preprocess_spm.seg).
# 220927-14:39:10,541 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 18 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:39:10,676 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103010_task_MOTOR/seg".
# 220927-14:39:10,725 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:39:12,526 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 17 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:40:07,438 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 348.81183s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:40:08,540 nipype.workflow INFO:
# 	 [Job 56] Completed (preprocess_spm.motion_correction).
# 220927-14:40:08,543 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 18 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:40:08,738 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103111_task_MOTOR/motion_correction".
# 220927-14:40:10,542 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 17 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:40:19,37 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:40:54,239 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 675.618443s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:40:54,564 nipype.workflow INFO:
# 	 [Job 53] Completed (preprocess_spm.seg).
# 220927-14:40:54,566 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 17 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:40:54,767 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103111_task_MOTOR/seg".
# 220927-14:40:54,863 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:40:56,569 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 16 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:41:33,392 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 345.488685s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:41:34,563 nipype.workflow INFO:
# 	 [Job 58] Completed (preprocess_spm.motion_correction).
# 220927-14:41:34,565 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 17 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:41:34,736 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103212_task_MOTOR/motion_correction".
# 220927-14:41:36,564 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 16 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:41:40,542 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 695.926677s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:41:42,570 nipype.workflow INFO:
# 	 [Job 55] Completed (preprocess_spm.seg).
# 220927-14:41:42,575 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 16 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:41:42,601 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:41:42,751 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103212_task_MOTOR/seg".
# 220927-14:41:42,797 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:41:44,571 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 15 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:45:13,38 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 642.395175s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:45:14,634 nipype.workflow INFO:
# 	 [Job 57] Completed (preprocess_spm.seg).
# 220927-14:45:14,636 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 15 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# 220927-14:45:14,821 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103414_task_MOTOR/motion_correction".
# 220927-14:45:16,635 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 14 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
# 220927-14:45:24,44 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:45:56,577 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 337.522459s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:45:58,656 nipype.workflow INFO:
# 	 [Job 60] Completed (preprocess_spm.motion_correction).
# 220927-14:45:58,660 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 15 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:45:58,900 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.seg" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103414_task_MOTOR/seg".
# 220927-14:45:58,963 nipype.workflow INFO:
# 	 [Node] Executing "seg" <nipype.interfaces.spm.preprocess.NewSegment>
# 220927-14:46:00,637 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 14 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:47:14,671 nipype.workflow INFO:
# 	 [Node] Finished "motion_correction", elapsed time 332.055397s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:47:16,669 nipype.workflow INFO:
# 	 [Job 62] Completed (preprocess_spm.motion_correction).
# 220927-14:47:16,679 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 15 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:47:16,891 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.motion_correction" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103515_task_MOTOR/motion_correction".
# 220927-14:47:18,672 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 14 jobs ready. Free memory (GB): 5.71/6.91, Free processors: 0/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:47:24,622 nipype.workflow INFO:
# 	 [Node] Executing "motion_correction" <nipype.interfaces.spm.preprocess.Realign>
# 220927-14:50:09,359 nipype.workflow INFO:
# 	 [Node] Finished "seg", elapsed time 658.61876s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-14:50:10,716 nipype.workflow INFO:
# 	 [Job 59] Completed (preprocess_spm.seg).
# 220927-14:50:10,719 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 14 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.motion_correction
#                        * preprocess_spm.seg
#                        * preprocess_spm.seg
# 220927-14:50:10,901 nipype.workflow INFO:
# ...
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:25,436 nipype.workflow INFO:
# 	 [Node] Finished "smooth", elapsed time 366.070592s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-15:21:25,686 nipype.workflow INFO:
# 	 [Job 106] Completed (preprocess_spm.smooth).
# 220927-15:21:25,690 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 9 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:25,921 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_101915_task_MOTOR/datasink_preproc".
# 220927-15:21:26,32 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:26,157 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.117306s.
# 220927-15:21:27,688 nipype.workflow INFO:
# 	 [Job 112] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:27,693 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 8 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:27,814 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102008_task_MOTOR/datasink_preproc".
# 220927-15:21:27,910 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:28,23 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.109875s.
# 220927-15:21:29,690 nipype.workflow INFO:
# 	 [Job 113] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:29,698 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 7 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:29,830 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102109_task_MOTOR/datasink_preproc".
# 220927-15:21:29,950 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:30,84 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.12407s.
# 220927-15:21:31,693 nipype.workflow INFO:
# 	 [Job 114] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:31,697 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 6 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:31,809 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102311_task_MOTOR/datasink_preproc".
# 220927-15:21:31,892 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:32,0 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.104779s.
# 220927-15:21:33,696 nipype.workflow INFO:
# 	 [Job 115] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:33,703 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 5 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:33,847 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102513_task_MOTOR/datasink_preproc".
# 220927-15:21:33,944 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:34,76 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.128805s.
# 220927-15:21:35,698 nipype.workflow INFO:
# 	 [Job 116] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:35,705 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 4 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:35,842 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102614_task_MOTOR/datasink_preproc".
# 220927-15:21:35,929 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:36,58 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.126465s.
# 220927-15:21:37,699 nipype.workflow INFO:
# 	 [Job 117] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:37,701 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 3 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:37,916 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102715_task_MOTOR/datasink_preproc".
# 220927-15:21:38,23 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:38,143 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.11161s.
# 220927-15:21:39,702 nipype.workflow INFO:
# 	 [Job 118] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:39,706 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 2 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:39,859 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_102816_task_MOTOR/datasink_preproc".
# 220927-15:21:39,953 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:40,34 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.07864s.
# 220927-15:21:41,704 nipype.workflow INFO:
# 	 [Job 119] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:41,707 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 1 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:21:41,822 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103010_task_MOTOR/datasink_preproc".
# 220927-15:21:41,925 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:21:42,50 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.114221s.
# 220927-15:21:43,706 nipype.workflow INFO:
# 	 [Job 120] Completed (preprocess_spm.datasink_preproc).
# 220927-15:21:43,708 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 5.91/6.91, Free processors: 1/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:23:03,208 nipype.workflow INFO:
# 	 [Node] Finished "smooth", elapsed time 353.79271s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-15:23:03,736 nipype.workflow INFO:
# 	 [Job 107] Completed (preprocess_spm.smooth).
# 220927-15:23:03,739 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 2/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:23:03,899 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103111_task_MOTOR/datasink_preproc".
# 220927-15:23:03,983 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:23:04,91 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.105315s.
# 220927-15:23:05,739 nipype.workflow INFO:
# 	 [Job 121] Completed (preprocess_spm.datasink_preproc).
# 220927-15:23:05,744 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 2/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:23:10,989 nipype.workflow INFO:
# 	 [Node] Finished "smooth", elapsed time 345.566823s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-15:23:11,743 nipype.workflow INFO:
# 	 [Job 108] Completed (preprocess_spm.smooth).
# 220927-15:23:11,747 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 3/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:23:11,897 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103212_task_MOTOR/datasink_preproc".
# 220927-15:23:11,973 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:23:12,68 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.08659s.
# 220927-15:23:13,745 nipype.workflow INFO:
# 	 [Job 122] Completed (preprocess_spm.datasink_preproc).
# 220927-15:23:13,753 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 3/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:23:36,761 nipype.workflow INFO:
# 	 [Node] Finished "smooth", elapsed time 329.289404s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-15:23:37,743 nipype.workflow INFO:
# 	 [Job 109] Completed (preprocess_spm.smooth).
# 220927-15:23:37,747 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 6.51/6.91, Free processors: 4/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:23:37,886 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103414_task_MOTOR/datasink_preproc".
# 220927-15:23:37,937 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:23:37,994 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.051129s.
# 220927-15:23:39,745 nipype.workflow INFO:
# 	 [Job 123] Completed (preprocess_spm.datasink_preproc).
# 220927-15:23:39,748 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 6.51/6.91, Free processors: 4/6.
#                      Currently running:
#                        * preprocess_spm.smooth
#                        * preprocess_spm.smooth
# 220927-15:24:01,455 nipype.workflow INFO:
# 	 [Node] Finished "smooth", elapsed time 303.978178s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-15:24:01,735 nipype.workflow INFO:
# 	 [Job 110] Completed (preprocess_spm.smooth).
# 220927-15:24:01,739 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 5/6.
#                      Currently running:
#                        * preprocess_spm.smooth
# 220927-15:24:01,848 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103515_task_MOTOR/datasink_preproc".
# 220927-15:24:01,889 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:24:01,936 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.042638s.
# 220927-15:24:03,736 nipype.workflow INFO:
# 	 [Job 124] Completed (preprocess_spm.datasink_preproc).
# 220927-15:24:03,738 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 5/6.
#                      Currently running:
#                        * preprocess_spm.smooth
# 220927-15:24:04,465 nipype.workflow INFO:
# 	 [Node] Finished "smooth", elapsed time 298.973066s.
# stty: 'standard input': Inappropriate ioctl for device
# 220927-15:24:05,746 nipype.workflow INFO:
# 	 [Job 111] Completed (preprocess_spm.smooth).
# 220927-15:24:05,753 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 6/6.
# 220927-15:24:05,845 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocess_spm.datasink_preproc" in "/home/hcp/spm_preprocessing/intermediate_results/preprocess_spm/_fwhm_8_subject_id_103818_task_MOTOR/datasink_preproc".
# 220927-15:24:05,875 nipype.workflow INFO:
# 	 [Node] Executing "datasink_preproc" <nipype.interfaces.io.DataSink>
# 220927-15:24:05,924 nipype.workflow INFO:
# 	 [Node] Finished "datasink_preproc", elapsed time 0.046058s.
# 220927-15:24:07,752 nipype.workflow INFO:
# 	 [Job 125] Completed (preprocess_spm.datasink_preproc).
# 220927-15:24:07,755 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 6/6.

# %%
from nilearn import image, plotting

np_img = '../spm_preprocessing/preprocess_spm/_fwhm_8_subject_id_100206_task_MOTOR/swr100206_3T_tfMRI_MOTOR_LR.nii'

plotting.plot_img(image.mean_img(np_img), cut_coords=(0, -10, 28), title = 'Nipype')

# %%
param_file = opj(output_dir, 'preprocess_spm', '_fwhm_{fwhm}_subject_id_{subject_id}_task_{task}',
                    'rp_{subject_id}_3T_tfMRI_{task}_LR.txt')

func_file = opj(output_dir, 'preprocess_spm', '_fwhm_{fwhm}_subject_id_{subject_id}_task_{task}',
                'swr{subject_id}_3T_tfMRI_{task}_LR.nii')

# %%
for subs in subject_list:
    l1_analysis = spm_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, [subs], task_list, 
                                                contrast_list, fwhm_list, param_file, func_file)
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 220928-07:51:57,672 nipype.workflow INFO:
# 	 Workflow l1_analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 220928-07:51:57,775 nipype.workflow INFO:
# 	 Running in parallel.
# 220928-07:51:57,826 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:51:57,945 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_102614_task_MOTOR/selectfiles".
# 220928-07:51:57,957 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_102614_task_MOTOR/selectfiles".
# 220928-07:51:57,988 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_102614_task_MOTOR/selectfiles".
# 220928-07:51:58,6 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_102614_task_MOTOR/selectfiles".
# 220928-07:51:58,48 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:51:58,57 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:51:58,64 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.004611s.
# 220928-07:51:58,87 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.005215s.
# 220928-07:51:58,93 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:51:58,101 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:51:58,111 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.006219s.
# 220928-07:51:58,130 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.007254s.
# 220928-07:51:59,830 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis.selectfiles).
# 220928-07:51:59,835 nipype.workflow INFO:
# 	 [Job 1] Completed (l1_analysis.selectfiles).
# 220928-07:51:59,838 nipype.workflow INFO:
# 	 [Job 2] Completed (l1_analysis.selectfiles).
# 220928-07:51:59,842 nipype.workflow INFO:
# 	 [Job 3] Completed (l1_analysis.selectfiles).
# 220928-07:51:59,847 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:51:59,965 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_102614_task_MOTOR/selectfiles".
# 220928-07:51:59,991 nipype.workflow INFO:
# 	 [Job 5] Cached (l1_analysis.subject_infos).
# 220928-07:52:00,22 nipype.workflow INFO:
# 	 [Job 6] Cached (l1_analysis.subject_infos).
# 220928-07:52:00,27 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:52:00,38 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.00265s.
# 220928-07:52:00,56 nipype.workflow INFO:
# 	 [Job 7] Cached (l1_analysis.subject_infos).
# 220928-07:52:01,809 nipype.workflow INFO:
# 	 [Job 4] Completed (l1_analysis.selectfiles).
# 220928-07:52:01,813 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:52:01,898 nipype.workflow INFO:
# 	 [Job 8] Cached (l1_analysis.subject_infos).
# 220928-07:52:01,920 nipype.workflow INFO:
# 	 [Job 9] Cached (l1_analysis.subject_infos).
# 220928-07:52:01,941 nipype.workflow INFO:
# 	 [Job 10] Cached (l1_analysis.specify_model).
# 220928-07:52:01,956 nipype.workflow INFO:
# 	 [Job 11] Cached (l1_analysis.specify_model).
# 220928-07:52:03,892 nipype.workflow INFO:
# 	 [Job 12] Cached (l1_analysis.specify_model).
# 220928-07:52:03,911 nipype.workflow INFO:
# 	 [Job 13] Cached (l1_analysis.specify_model).
# 220928-07:52:03,939 nipype.workflow INFO:
# 	 [Job 14] Cached (l1_analysis.specify_model).
# 220928-07:52:03,981 nipype.workflow INFO:
# 	 [Job 15] Cached (l1_analysis.l1_design).
# 220928-07:52:05,901 nipype.workflow INFO:
# 	 [Job 16] Cached (l1_analysis.l1_design).
# 220928-07:52:05,941 nipype.workflow INFO:
# 	 [Job 17] Cached (l1_analysis.l1_design).
# 220928-07:52:05,977 nipype.workflow INFO:
# 	 [Job 18] Cached (l1_analysis.l1_design).
# 220928-07:52:06,8 nipype.workflow INFO:
# 	 [Job 19] Cached (l1_analysis.l1_design).
# 220928-07:52:07,884 nipype.workflow INFO:
# 	 [Job 20] Cached (l1_analysis.l1_estimate).
# 220928-07:52:07,890 nipype.workflow INFO:
# 	 [Job 21] Cached (l1_analysis.l1_estimate).
# 220928-07:52:07,900 nipype.workflow INFO:
# 	 [Job 22] Cached (l1_analysis.l1_estimate).
# 220928-07:52:07,907 nipype.workflow INFO:
# 	 [Job 23] Cached (l1_analysis.l1_estimate).
# 220928-07:52:09,888 nipype.workflow INFO:
# 	 [Job 24] Cached (l1_analysis.l1_estimate).
# 220928-07:52:09,899 nipype.workflow INFO:
# 	 [Job 25] Cached (l1_analysis.contrast_estimate).
# 220928-07:52:09,910 nipype.workflow INFO:
# 	 [Job 26] Cached (l1_analysis.contrast_estimate).
# 220928-07:52:09,925 nipype.workflow INFO:
# 	 [Job 27] Cached (l1_analysis.contrast_estimate).
# 220928-07:52:11,899 nipype.workflow INFO:
# 	 [Job 28] Cached (l1_analysis.contrast_estimate).
# 220928-07:52:11,910 nipype.workflow INFO:
# 	 [Job 29] Cached (l1_analysis.contrast_estimate).
# 220928-07:52:11,922 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_102614_task_MOTOR/datasink".
# 220928-07:52:11,933 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_102614_task_MOTOR/datasink".
# 220928-07:52:11,975 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:52:11,982 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:52:11,995 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.01014s.
# 220928-07:52:12,16 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.032427s.
# 220928-07:52:13,832 nipype.workflow INFO:
# 	 [Job 30] Completed (l1_analysis.datasink).
# 220928-07:52:13,841 nipype.workflow INFO:
# 	 [Job 31] Completed (l1_analysis.datasink).
# 220928-07:52:13,845 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:52:13,919 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_102614_task_MOTOR/datasink".
# 220928-07:52:13,934 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_102614_task_MOTOR/datasink".
# 220928-07:52:13,952 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_102614_task_MOTOR/datasink".
# 220928-07:52:13,970 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:52:13,981 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00717s.
# 220928-07:52:13,997 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:52:14,19 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:52:14,38 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.035028s.
# 220928-07:52:14,59 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.03602s.
# 220928-07:52:15,831 nipype.workflow INFO:
# 	 [Job 32] Completed (l1_analysis.datasink).
# 220928-07:52:15,833 nipype.workflow INFO:
# 	 [Job 33] Completed (l1_analysis.datasink).
# 220928-07:52:15,834 nipype.workflow INFO:
# 	 [Job 34] Completed (l1_analysis.datasink).
# 220928-07:52:15,837 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:52:17,873 nipype.workflow INFO:
# 	 Workflow l1_analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 220928-07:52:17,988 nipype.workflow INFO:
# 	 Running in parallel.
# 220928-07:52:17,991 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:52:18,93 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_101410_task_MOTOR/selectfiles".
# 220928-07:52:18,98 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_101410_task_MOTOR/selectfiles".
# 220928-07:52:18,107 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_101410_task_MOTOR/selectfiles".
# 220928-07:52:18,107 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_101410_task_MOTOR/selectfiles".
# 220928-07:52:18,172 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:52:18,183 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:52:18,193 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:52:18,202 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:52:18,213 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.010227s.
# 220928-07:52:18,215 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.006483s.
# 220928-07:52:18,213 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.029221s.
# 220928-07:52:18,213 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.021885s.
# 220928-07:52:19,995 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis.selectfiles).
# 220928-07:52:19,998 nipype.workflow INFO:
# 	 [Job 1] Completed (l1_analysis.selectfiles).
# 220928-07:52:20,0 nipype.workflow INFO:
# 	 [Job 2] Completed (l1_analysis.selectfiles).
# 220928-07:52:20,3 nipype.workflow INFO:
# 	 [Job 3] Completed (l1_analysis.selectfiles).
# 220928-07:52:20,6 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:52:20,117 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_101410_task_MOTOR/selectfiles".
# 220928-07:52:20,119 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_101410_task_MOTOR/subject_infos".
# 220928-07:52:20,119 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_101410_task_MOTOR/subject_infos".
# 220928-07:52:20,125 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_101410_task_MOTOR/subject_infos".
# 220928-07:52:20,181 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:52:20,190 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.002255s.
# 220928-07:52:20,192 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:52:20,216 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.015104s.
# 220928-07:52:20,222 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:52:20,231 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:52:20,241 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.008419s.
# 220928-07:52:20,252 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.013266s.
# 220928-07:52:21,996 nipype.workflow INFO:
# 	 [Job 4] Completed (l1_analysis.selectfiles).
# 220928-07:52:22,1 nipype.workflow INFO:
# 	 [Job 5] Completed (l1_analysis.subject_infos).
# 220928-07:52:22,5 nipype.workflow INFO:
# 	 [Job 6] Completed (l1_analysis.subject_infos).
# 220928-07:52:22,9 nipype.workflow INFO:
# 	 [Job 7] Completed (l1_analysis.subject_infos).
# 220928-07:52:22,14 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:52:22,84 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_101410_task_MOTOR/subject_infos".
# 220928-07:52:22,86 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_101410_task_MOTOR/subject_infos".
# 220928-07:52:22,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_101410_task_MOTOR/specify_model".
# 220928-07:52:22,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_101410_task_MOTOR/specify_model".
# 220928-07:52:22,155 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:52:22,170 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.009929s.
# 220928-07:52:22,197 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:52:22,216 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.009222s.
# 220928-07:52:22,232 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:52:22,236 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:52:22,256 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.019685s.
# 220928-07:52:22,269 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.026912s.
# 220928-07:52:23,998 nipype.workflow INFO:
# 	 [Job 8] Completed (l1_analysis.subject_infos).
# 220928-07:52:24,0 nipype.workflow INFO:
# 	 [Job 9] Completed (l1_analysis.subject_infos).
# 220928-07:52:24,2 nipype.workflow INFO:
# 	 [Job 10] Completed (l1_analysis.specify_model).
# 220928-07:52:24,4 nipype.workflow INFO:
# 	 [Job 11] Completed (l1_analysis.specify_model).
# 220928-07:52:24,8 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:52:24,80 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_101410_task_MOTOR/specify_model".
# 220928-07:52:24,84 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_101410_task_MOTOR/specify_model".
# 220928-07:52:24,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_101410_task_MOTOR/l1_design".
# 220928-07:52:24,90 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_101410_task_MOTOR/specify_model".
# 220928-07:52:24,207 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:52:24,226 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:52:24,224 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.012606s.
# 220928-07:52:24,233 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:52:24,249 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.019136s.
# 220928-07:52:24,259 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.007487s.
# 220928-07:52:24,309 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:52:26,0 nipype.workflow INFO:
# 	 [Job 12] Completed (l1_analysis.specify_model).
# 220928-07:52:26,1 nipype.workflow INFO:
# 	 [Job 13] Completed (l1_analysis.specify_model).
# 220928-07:52:26,5 nipype.workflow INFO:
# 	 [Job 14] Completed (l1_analysis.specify_model).
# 220928-07:52:26,9 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_design
# 220928-07:52:26,73 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_101410_task_MOTOR/l1_design".
# 220928-07:52:26,74 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_101410_task_MOTOR/l1_design".
# 220928-07:52:26,76 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_101410_task_MOTOR/l1_design".
# 220928-07:52:26,210 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:52:26,224 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:52:26,235 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:52:28,3 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
# 220928-07:52:44,578 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 20.264929s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:52:45,999 nipype.workflow INFO:
# 	 [Job 15] Completed (l1_analysis.l1_design).
# 220928-07:52:46,5 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
# 220928-07:52:46,80 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_101410_task_MOTOR/l1_design".
# 220928-07:52:46,104 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 19.851298s.
# 220928-07:52:46,204 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:52:46,237 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 20.015564s.
# 220928-07:52:46,249 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 20.015035s.
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:52:48,1 nipype.workflow INFO:
# 	 [Job 16] Completed (l1_analysis.l1_design).
# 220928-07:52:48,3 nipype.workflow INFO:
# 	 [Job 17] Completed (l1_analysis.l1_design).
# 220928-07:52:48,4 nipype.workflow INFO:
# 	 [Job 18] Completed (l1_analysis.l1_design).
# 220928-07:52:48,7 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_design
# 220928-07:52:48,69 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_101410_task_MOTOR/l1_estimate".
# 220928-07:52:48,74 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_101410_task_MOTOR/l1_estimate".
# 220928-07:52:48,75 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_101410_task_MOTOR/l1_estimate".
# 220928-07:52:48,187 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:52:48,217 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:52:48,224 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:52:50,3 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_design
# 220928-07:53:03,302 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 17.094668s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:53:03,994 nipype.workflow INFO:
# 	 [Job 19] Completed (l1_analysis.l1_design).
# 220928-07:53:03,996 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:53:04,99 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_101410_task_MOTOR/l1_estimate".
# 220928-07:53:04,211 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:53:05,997 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:54:07,744 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 79.523085s.
# 220928-07:54:07,758 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 79.521516s.
# 220928-07:54:07,830 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 79.635341s.
# 220928-07:54:08,10 nipype.workflow INFO:
# 	 [Job 20] Completed (l1_analysis.l1_estimate).
# 220928-07:54:08,30 nipype.workflow INFO:
# 	 [Job 21] Completed (l1_analysis.l1_estimate).
# 220928-07:54:08,35 nipype.workflow INFO:
# 	 [Job 22] Completed (l1_analysis.l1_estimate).
# 220928-07:54:08,43 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
# 220928-07:54:08,595 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_101410_task_MOTOR/l1_estimate".
# 220928-07:54:08,597 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_101410_task_MOTOR/contrast_estimate".
# 220928-07:54:08,606 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_101410_task_MOTOR/contrast_estimate".
# 220928-07:54:08,728 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:54:08,918 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:54:08,929 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:54:10,11 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:54:20,285 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 76.069764s.
# 220928-07:54:22,23 nipype.workflow INFO:
# 	 [Job 23] Completed (l1_analysis.l1_estimate).
# 220928-07:54:22,26 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:54:22,103 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_101410_task_MOTOR/contrast_estimate".
# 220928-07:54:22,277 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:54:24,25 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:54:25,901 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 16.978175s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:54:26,27 nipype.workflow INFO:
# 	 [Job 25] Completed (l1_analysis.contrast_estimate).
# 220928-07:54:26,30 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:54:26,98 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_101410_task_MOTOR/contrast_estimate".
# 220928-07:54:26,337 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:54:26,840 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 17.905651s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:54:28,29 nipype.workflow INFO:
# 	 [Job 26] Completed (l1_analysis.contrast_estimate).
# 220928-07:54:28,34 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:54:28,117 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_101410_task_MOTOR/datasink".
# 220928-07:54:28,171 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:54:28,337 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.161898s.
# 220928-07:54:30,8 nipype.workflow INFO:
# 	 [Job 30] Completed (l1_analysis.datasink).
# 220928-07:54:30,12 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:54:30,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_101410_task_MOTOR/datasink".
# 220928-07:54:30,147 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:54:30,422 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.261489s.
# 220928-07:54:32,9 nipype.workflow INFO:
# 	 [Job 31] Completed (l1_analysis.datasink).
# 220928-07:54:32,13 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:54:35,381 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 13.094476s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:54:36,13 nipype.workflow INFO:
# 	 [Job 27] Completed (l1_analysis.contrast_estimate).
# 220928-07:54:36,15 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 6.51/6.91, Free processors: 2/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:54:36,131 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_101410_task_MOTOR/datasink".
# 220928-07:54:36,164 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:54:36,193 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.027755s.
# 220928-07:54:37,291 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 10.949556s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:54:38,14 nipype.workflow INFO:
# 	 [Job 28] Completed (l1_analysis.contrast_estimate).
# 220928-07:54:38,16 nipype.workflow INFO:
# 	 [Job 32] Completed (l1_analysis.datasink).
# 220928-07:54:38,20 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
# 220928-07:54:38,83 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_101410_task_MOTOR/datasink".
# 220928-07:54:38,115 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:54:38,138 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.018356s.
# 220928-07:54:40,15 nipype.workflow INFO:
# 	 [Job 33] Completed (l1_analysis.datasink).
# 220928-07:54:40,17 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
# 220928-07:55:05,854 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 57.12068s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:55:06,21 nipype.workflow INFO:
# 	 [Job 24] Completed (l1_analysis.l1_estimate).
# 220928-07:55:06,26 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:55:06,91 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_101410_task_MOTOR/contrast_estimate".
# 220928-07:55:06,239 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:55:08,21 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
# 220928-07:55:14,611 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 8.369478s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:55:16,30 nipype.workflow INFO:
# 	 [Job 29] Completed (l1_analysis.contrast_estimate).
# 220928-07:55:16,32 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:55:16,89 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_101410_task_MOTOR/datasink".
# 220928-07:55:16,135 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:55:16,287 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.145091s.
# 220928-07:55:18,36 nipype.workflow INFO:
# 	 [Job 34] Completed (l1_analysis.datasink).
# 220928-07:55:18,41 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:55:20,74 nipype.workflow INFO:
# 	 Workflow l1_analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 220928-07:55:20,169 nipype.workflow INFO:
# 	 Running in parallel.
# 220928-07:55:20,174 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:55:20,273 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_100610_task_MOTOR/selectfiles".
# 220928-07:55:20,269 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_100610_task_MOTOR/selectfiles".
# 220928-07:55:20,278 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_100610_task_MOTOR/selectfiles".
# 220928-07:55:20,276 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_100610_task_MOTOR/selectfiles".
# 220928-07:55:20,336 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:55:20,352 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:55:20,360 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:55:20,368 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:55:20,379 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.034531s.
# 220928-07:55:20,381 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.006154s.
# 220928-07:55:20,379 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.009005s.
# 220928-07:55:20,380 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.017767s.
# 220928-07:55:22,180 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis.selectfiles).
# 220928-07:55:22,186 nipype.workflow INFO:
# 	 [Job 1] Completed (l1_analysis.selectfiles).
# 220928-07:55:22,189 nipype.workflow INFO:
# 	 [Job 2] Completed (l1_analysis.selectfiles).
# 220928-07:55:22,192 nipype.workflow INFO:
# 	 [Job 3] Completed (l1_analysis.selectfiles).
# 220928-07:55:22,199 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:55:22,287 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.selectfiles" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_100610_task_MOTOR/selectfiles".
# 220928-07:55:22,288 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_100610_task_MOTOR/subject_infos".
# 220928-07:55:22,293 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_100610_task_MOTOR/subject_infos".
# 220928-07:55:22,290 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_100610_task_MOTOR/subject_infos".
# 220928-07:55:22,325 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220928-07:55:22,332 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.001553s.
# 220928-07:55:22,372 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:55:22,385 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:55:22,391 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.014652s.
# 220928-07:55:22,395 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:55:22,399 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.004425s.
# 220928-07:55:22,409 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.006468s.
# 220928-07:55:24,181 nipype.workflow INFO:
# 	 [Job 4] Completed (l1_analysis.selectfiles).
# 220928-07:55:24,184 nipype.workflow INFO:
# 	 [Job 5] Completed (l1_analysis.subject_infos).
# 220928-07:55:24,187 nipype.workflow INFO:
# 	 [Job 6] Completed (l1_analysis.subject_infos).
# 220928-07:55:24,189 nipype.workflow INFO:
# 	 [Job 7] Completed (l1_analysis.subject_infos).
# 220928-07:55:24,194 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:55:24,255 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_100610_task_MOTOR/subject_infos".
# 220928-07:55:24,258 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_100610_task_MOTOR/specify_model".
# 220928-07:55:24,256 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.subject_infos" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_100610_task_MOTOR/subject_infos".
# 220928-07:55:24,261 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_100610_task_MOTOR/specify_model".
# 220928-07:55:24,322 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:55:24,336 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.009723s.
# 220928-07:55:24,350 nipype.workflow INFO:
# 	 [Node] Executing "subject_infos" <nipype.interfaces.utility.wrappers.Function>
# 220928-07:55:24,362 nipype.workflow INFO:
# 	 [Node] Finished "subject_infos", elapsed time 0.003196s.
# 220928-07:55:24,371 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:55:24,387 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:55:24,394 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.019326s.
# 220928-07:55:24,413 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.016086s.
# 220928-07:55:26,185 nipype.workflow INFO:
# 	 [Job 8] Completed (l1_analysis.subject_infos).
# 220928-07:55:26,189 nipype.workflow INFO:
# 	 [Job 9] Completed (l1_analysis.subject_infos).
# 220928-07:55:26,193 nipype.workflow INFO:
# 	 [Job 10] Completed (l1_analysis.specify_model).
# 220928-07:55:26,199 nipype.workflow INFO:
# 	 [Job 11] Completed (l1_analysis.specify_model).
# 220928-07:55:26,203 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:55:26,272 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_100610_task_MOTOR/specify_model".
# 220928-07:55:26,273 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_100610_task_MOTOR/specify_model".
# 220928-07:55:26,275 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.specify_model" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_100610_task_MOTOR/specify_model".
# 220928-07:55:26,279 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_100610_task_MOTOR/l1_design".
# 220928-07:55:26,364 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:55:26,376 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:55:26,376 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.009981s.
# 220928-07:55:26,383 nipype.workflow INFO:
# 	 [Node] Executing "specify_model" <nipype.algorithms.modelgen.SpecifySPMModel>
# 220928-07:55:26,400 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.020931s.
# 220928-07:55:26,398 nipype.workflow INFO:
# 	 [Node] Finished "specify_model", elapsed time 0.010246s.
# 220928-07:55:26,432 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:55:28,185 nipype.workflow INFO:
# 	 [Job 12] Completed (l1_analysis.specify_model).
# 220928-07:55:28,187 nipype.workflow INFO:
# 	 [Job 13] Completed (l1_analysis.specify_model).
# 220928-07:55:28,189 nipype.workflow INFO:
# 	 [Job 14] Completed (l1_analysis.specify_model).
# 220928-07:55:28,192 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_design
# 220928-07:55:28,266 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_100610_task_MOTOR/l1_design".
# 220928-07:55:28,271 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_100610_task_MOTOR/l1_design".
# 220928-07:55:28,274 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_100610_task_MOTOR/l1_design".
# 220928-07:55:28,418 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:55:28,438 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:55:28,426 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:55:30,165 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
# 220928-07:55:44,767 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 18.330715s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:55:46,178 nipype.workflow INFO:
# 	 [Job 15] Completed (l1_analysis.l1_design).
# 220928-07:55:46,181 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
#                        * l1_analysis.l1_design
# 220928-07:55:46,245 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_design" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_100610_task_MOTOR/l1_design".
# 220928-07:55:46,419 nipype.workflow INFO:
# 	 [Node] Executing "l1_design" <nipype.interfaces.spm.model.Level1Design>
# 220928-07:55:46,465 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 18.036114s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:55:47,78 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 18.627225s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:55:47,521 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 19.078957s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:55:48,180 nipype.workflow INFO:
# 	 [Job 16] Completed (l1_analysis.l1_design).
# 220928-07:55:48,181 nipype.workflow INFO:
# 	 [Job 17] Completed (l1_analysis.l1_design).
# 220928-07:55:48,183 nipype.workflow INFO:
# 	 [Job 18] Completed (l1_analysis.l1_design).
# 220928-07:55:48,187 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_design
# 220928-07:55:48,248 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_100610_task_MOTOR/l1_estimate".
# 220928-07:55:48,261 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_100610_task_MOTOR/l1_estimate".
# 220928-07:55:48,261 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_100610_task_MOTOR/l1_estimate".
# 220928-07:55:48,398 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:55:48,438 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:55:48,435 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:55:50,182 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_design
# 220928-07:56:02,380 nipype.workflow INFO:
# 	 [Node] Finished "l1_design", elapsed time 15.95744s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:56:04,174 nipype.workflow INFO:
# 	 [Job 19] Completed (l1_analysis.l1_design).
# 220928-07:56:04,177 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:56:04,291 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_100610_task_MOTOR/l1_estimate".
# 220928-07:56:04,382 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:56:06,176 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:57:01,12 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 72.609708s.
# 220928-07:57:01,52 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 72.60896s.
# 220928-07:57:01,93 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 72.643098s.
# 220928-07:57:02,196 nipype.workflow INFO:
# 	 [Job 20] Completed (l1_analysis.l1_estimate).
# 220928-07:57:02,212 nipype.workflow INFO:
# 	 [Job 21] Completed (l1_analysis.l1_estimate).
# 220928-07:57:02,214 nipype.workflow INFO:
# 	 [Job 22] Completed (l1_analysis.l1_estimate).
# 220928-07:57:02,220 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
# 220928-07:57:02,725 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.l1_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_100610_task_MOTOR/l1_estimate".
# 220928-07:57:02,727 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_100610_task_MOTOR/contrast_estimate".
# 220928-07:57:02,731 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_100610_task_MOTOR/contrast_estimate".
# 220928-07:57:02,854 nipype.workflow INFO:
# 	 [Node] Executing "l1_estimate" <nipype.interfaces.spm.model.EstimateModel>
# 220928-07:57:03,40 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:57:03,70 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:57:04,202 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 6.11/6.91, Free processors: 0/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
#                        * l1_analysis.l1_estimate
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:57:18,415 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 74.021852s.
# 220928-07:57:19,89 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 16.00936s.
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:57:19,260 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 16.213999s.
# 220928-07:57:20,212 nipype.workflow INFO:
# 	 [Job 23] Completed (l1_analysis.l1_estimate).
# 220928-07:57:20,213 nipype.workflow INFO:
# 	 [Job 25] Completed (l1_analysis.contrast_estimate).
# 220928-07:57:20,215 nipype.workflow INFO:
# 	 [Job 26] Completed (l1_analysis.contrast_estimate).
# 220928-07:57:20,221 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
# 220928-07:57:20,286 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_100610_task_MOTOR/contrast_estimate".
# 220928-07:57:20,293 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lf_fwhm_8_subject_id_100610_task_MOTOR/datasink".
# 220928-07:57:20,291 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_100610_task_MOTOR/contrast_estimate".
# 220928-07:57:20,358 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:57:20,607 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.244269s.
# 220928-07:57:20,616 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:57:20,661 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:57:22,213 nipype.workflow INFO:
# 	 [Job 30] Completed (l1_analysis.datasink).
# 220928-07:57:22,216 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:57:22,305 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rf_fwhm_8_subject_id_100610_task_MOTOR/datasink".
# 220928-07:57:22,355 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:57:22,589 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.2199s.
# 220928-07:57:24,216 nipype.workflow INFO:
# 	 [Job 31] Completed (l1_analysis.datasink).
# 220928-07:57:24,219 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 6.31/6.91, Free processors: 1/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.contrast_estimate
#                        * l1_analysis.l1_estimate
# 220928-07:57:31,482 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 10.814257s.
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:57:31,613 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 10.992882s.
# 220928-07:57:32,199 nipype.workflow INFO:
# 	 [Job 27] Completed (l1_analysis.contrast_estimate).
# 220928-07:57:32,201 nipype.workflow INFO:
# 	 [Job 28] Completed (l1_analysis.contrast_estimate).
# 220928-07:57:32,203 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
# 220928-07:57:32,265 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_rh_fwhm_8_subject_id_100610_task_MOTOR/datasink".
# 220928-07:57:32,270 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_lh_fwhm_8_subject_id_100610_task_MOTOR/datasink".
# 220928-07:57:32,309 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:57:32,310 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:57:32,369 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.04824s.
# 220928-07:57:32,504 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.19068s.
# 220928-07:57:34,201 nipype.workflow INFO:
# 	 [Job 32] Completed (l1_analysis.datasink).
# 220928-07:57:34,204 nipype.workflow INFO:
# 	 [Job 33] Completed (l1_analysis.datasink).
# 220928-07:57:34,207 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.l1_estimate
# 220928-07:57:59,581 nipype.workflow INFO:
# 	 [Node] Finished "l1_estimate", elapsed time 56.723952s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:58:00,199 nipype.workflow INFO:
# 	 [Job 24] Completed (l1_analysis.l1_estimate).
# 220928-07:58:00,201 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:58:00,267 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.contrast_estimate" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_100610_task_MOTOR/contrast_estimate".
# 220928-07:58:00,434 nipype.workflow INFO:
# 	 [Node] Executing "contrast_estimate" <nipype.interfaces.spm.model.EstimateContrast>
# 220928-07:58:02,199 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 6.71/6.91, Free processors: 3/4.
#                      Currently running:
#                        * l1_analysis.contrast_estimate
# 220928-07:58:09,230 nipype.workflow INFO:
# 	 [Node] Finished "contrast_estimate", elapsed time 8.789683s.
# stty: 'standard input': Inappropriate ioctl for device
# 220928-07:58:10,215 nipype.workflow INFO:
# 	 [Job 29] Completed (l1_analysis.contrast_estimate).
# 220928-07:58:10,220 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.
# 220928-07:58:10,286 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis.datasink" in "/home/hcp/spm_preprocessing/intermediate_results/l1_analysis/_contrast_t_fwhm_8_subject_id_100610_task_MOTOR/datasink".
# 220928-07:58:10,314 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220928-07:58:10,436 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.119326s.
# 220928-07:58:12,217 nipype.workflow INFO:
# 	 [Job 34] Completed (l1_analysis.datasink).
# 220928-07:58:12,223 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.91/6.91, Free processors: 4/4.

# %%
from nilearn import plotting
import nibabel as nib
from lib import processing
for sub in subject_list:
    #stat_map_fsl = f'/home/hcp/fsl_preprocessing/registration_fsl/_contrast_lf_fwhm_8_subject_id_{sub}_task_MOTOR/cope1_warp.nii.gz'
    #plotting.plot_stat_map(stat_map_fsl, title = 'FSL wrapped masked', cut_coords = (0, -20, 20))
    stat_map_spm = f'/home/hcp/spm_preprocessing/l1_analysis_spm/_contrast_lf_fwhm_8_subject_id_{sub}_task_MOTOR/con_0001.nii'
    #plotting.plot_stat_map(stat_map_spm, title = 'SPM not masked', cut_coords = (0, -20, 20))
    #fsl_contrast = processing.rescaling(stat_map_fsl, 0.01)
    spm_contrast = processing.rescaling(processing.masking(processing.resampling(stat_map_spm)), 0.4)
# Out:
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
# Masking image...
# Done.
# Rescaling data...
# Done.
